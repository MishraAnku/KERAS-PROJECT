# %% [markdown]
# In \[2\]:
#
#     # first neural network with keras tutorial
#     from numpy import loadtxt
#     from tensorflow.keras.models import Sequential
#     from tensorflow.keras.layers import Dense
#
# In \[3\]:
#
#     # load the dataset
#     dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
#     # split into input (X) and output (y) variables
#     X = dataset[:,0:8]
#     y = dataset[:,8]
#     ...
#
# Out\[3\]:
#
#     Ellipsis
#
# In \[8\]:
#
#     #  Define Keras Model
#
#     model = Sequential()
#     model.add(Dense(12, input_shape=(8,), activation='relu'))
#     model.add(Dense(8, activation='relu'))
#     model.add(Dense(1, activation='sigmoid'))
#     ...
#
#     # Note:  The most confusing thing here is that the shape of the input to the model is defined as an argument on the first hidden layer. This means that the line of code that adds the first Dense layer is doing two things, defining the input or visible layer and the first hidden layer.
#
#     WARNING:tensorflow:From C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Out\[8\]:
#
#     Ellipsis
#
# In \[9\]:
#
#     # Compile Keras Model
#
#     ...
#     # compile the keras model
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#     ...
#
#     WARNING:tensorflow:From C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Out\[9\]:
#
#     Ellipsis
#
# In \[10\]:
#
#     # Fit Keras Model
#
#     ...
#     # fit the keras model on the dataset
#     model.fit(X, y, epochs=150, batch_size=10)
#     ...
#
#     Epoch 1/150
#     WARNING:tensorflow:From C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
#     WARNING:tensorflow:From C:\Users\Amrendra Mishra\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
#     77/77 [==============================] - 1s 1ms/step - loss: 4.3815 - accuracy: 0.5729
#     Epoch 2/150
#     77/77 [==============================] - 0s 1ms/step - loss: 1.4657 - accuracy: 0.5586
#     Epoch 3/150
#     77/77 [==============================] - 0s 1ms/step - loss: 1.0102 - accuracy: 0.6016
#     Epoch 4/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.8676 - accuracy: 0.6393
#     Epoch 5/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.7767 - accuracy: 0.6458
#     Epoch 6/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.7283 - accuracy: 0.6536
#     Epoch 7/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6988 - accuracy: 0.6628
#     Epoch 8/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6774 - accuracy: 0.6667
#     Epoch 9/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6648 - accuracy: 0.6797
#     Epoch 10/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6451 - accuracy: 0.6745
#     Epoch 11/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6365 - accuracy: 0.6836
#     Epoch 12/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6289 - accuracy: 0.6810
#     Epoch 13/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6132 - accuracy: 0.6901
#     Epoch 14/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6074 - accuracy: 0.6810
#     Epoch 15/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6017 - accuracy: 0.6823
#     Epoch 16/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5962 - accuracy: 0.6875
#     Epoch 17/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5912 - accuracy: 0.7005
#     Epoch 18/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5963 - accuracy: 0.6862
#     Epoch 19/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5854 - accuracy: 0.7044
#     Epoch 20/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5860 - accuracy: 0.6927
#     Epoch 21/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5872 - accuracy: 0.6927
#     Epoch 22/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5838 - accuracy: 0.6927
#     Epoch 23/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5817 - accuracy: 0.6966
#     Epoch 24/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7018
#     Epoch 25/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5706 - accuracy: 0.6953
#     Epoch 26/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5723 - accuracy: 0.6966
#     Epoch 27/150
#     77/77 [==============================] - 0s 4ms/step - loss: 0.5651 - accuracy: 0.7018
#     Epoch 28/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5707 - accuracy: 0.7005
#     Epoch 29/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5654 - accuracy: 0.7109
#     Epoch 30/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5637 - accuracy: 0.7135
#     Epoch 31/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5675 - accuracy: 0.6966
#     Epoch 32/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5765 - accuracy: 0.7018
#     Epoch 33/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5597 - accuracy: 0.7057
#     Epoch 34/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5621 - accuracy: 0.6992
#     Epoch 35/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5597 - accuracy: 0.7044
#     Epoch 36/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5653 - accuracy: 0.7057
#     Epoch 37/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5627 - accuracy: 0.6927
#     Epoch 38/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.
150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5193 - accuracy: 0.7383
#     Epoch 106/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7292
#     Epoch 107/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5176 - accuracy: 0.7253
#     Epoch 108/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5164 - accuracy: 0.7357
#     Epoch 109/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5090 - accuracy: 0.7383
#     Epoch 110/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5179 - accuracy: 0.7240
#     Epoch 111/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5140 - accuracy: 0.7266
#     Epoch 112/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5147 - accuracy: 0.7409
#     Epoch 113/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5141 - accuracy: 0.7227
#     Epoch 114/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5102 - accuracy: 0.7409
#     Epoch 115/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5165 - accuracy: 0.7266
#     Epoch 116/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5187 - accuracy: 0.7214
#     Epoch 117/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5121 - accuracy: 0.7305
#     Epoch 118/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5218 - accuracy: 0.7188
#     Epoch 119/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5119 - accuracy: 0.7279
#     Epoch 120/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5177 - accuracy: 0.7240
#     Epoch 121/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5145 - accuracy: 0.7227
#     Epoch 122/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5113 - accuracy: 0.7357
#     Epoch 123/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5118 - accuracy: 0.7253
#     Epoch 124/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.7344
#     Epoch 125/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5035 - accuracy: 0.7331
#     Epoch 126/150
#     77/77 [==============================] - 0s 3ms/step - loss: 0.5107 - accuracy: 0.7227
#     Epoch 127/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5106 - accuracy: 0.7331
#     Epoch 128/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5136 - accuracy: 0.7253
#     Epoch 129/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5109 - accuracy: 0.7240
#     Epoch 130/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5056 - accuracy: 0.7292
#     Epoch 131/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5131 - accuracy: 0.7214
#     Epoch 132/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5072 - accuracy: 0.7331
#     Epoch 133/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5124 - accuracy: 0.7266
#     Epoch 134/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5032 - accuracy: 0.7357
#     Epoch 135/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5039 - accuracy: 0.7292
#     Epoch 136/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5101 - accuracy: 0.7240
#     Epoch 137/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5038 - accuracy: 0.7292
#     Epoch 138/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5086 - accuracy: 0.7422
#     Epoch 139/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5069 - accuracy: 0.7318
#     Epoch 140/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5019 - accuracy: 0.7370
#     Epoch 141/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5035 - accuracy: 0.7370
#     Epoch 142/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5038 - accuracy: 0.7318
#     Epoch 143/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5047 - accuracy: 0.7396
#     Epoch 144/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5068 - accuracy: 0.7396
#     Epoch 145/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5078 - accuracy: 0.7292
#     Epoch 146/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5055 - accuracy: 0.7383
#     Epoch 147/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5028 - accuracy: 0.7214
#     Epoch 148/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5018 - accuracy: 0.7305
#     Epoch 149/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4988 - accuracy: 0.7383
#     Epoch 150/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5065 - accuracy: 0.7331
#
# Out\[10\]:
#
#     Ellipsis
#
# In \[11\]:
#
#     # Evaluate Keras Model
#
#     ...
#     # evaluate the keras model
#     _, accuracy = model.evaluate(X, y)
#     print('Accuracy: %.2f' % (accuracy*100))
#
#     24/24 [==============================] - 0s 1ms/step - loss: 0.4955 - accuracy: 0.7344
#     Accuracy: 73.44
#
# In \[12\]:
#
#     # Tie It All Together
#
#     # first neural network with keras tutorial
#     from numpy import loadtxt
#     from tensorflow.keras.models import Sequential
#     from tensorflow.keras.layers import Dense
#     # load the dataset
#     dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
#     # split into input (X) and output (y) variables
#     X = dataset[:,0:8]
#     y = dataset[:,8]
#     # define the keras model
#     model = Sequential()
#     model.add(Dense(12, input_shape=(8,), activation='relu'))
#     model.add(Dense(8, activation='relu'))
#     model.add(Dense(1, activation='sigmoid'))
#     # compile the keras model
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#     # fit the keras model on the dataset
#     model.fit(X, y, epochs=150, batch_size=10)
#     # evaluate the keras model
#     _, accuracy = model.evaluate(X, y)
#     print('Accuracy: %.2f' % (accuracy*100))
#
#     Epoch 1/150
#     77/77 [==============================] - 1s 2ms/step - loss: 4.4217 - accuracy: 0.4857
#     Epoch 2/150
#     77/77 [==============================] - 0s 2ms/step - loss: 2.9627 - accuracy: 0.4896
#     Epoch 3/150
#     77/77 [==============================] - 0s 2ms/step - loss: 2.1008 - accuracy: 0.4948
#     Epoch 4/150
#     77/77 [==============================] - 0s 1ms/step - loss: 1.4961 - accuracy: 0.5339
#     Epoch 5/150
#     77/77 [==============================] - 0s 2ms/step - loss: 1.2073 - accuracy: 0.5703
#     Epoch 6/150
#     77/77 [==============================] - 0s 1ms/step - loss: 1.0554 - accuracy: 0.5703
#     Epoch 7/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.9527 - accuracy: 0.5833
#     Epoch 8/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.8915 - accuracy: 0.6068
#     Epoch 9/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.8428 - accuracy: 0.6133
#     Epoch 10/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.7415 - accuracy: 0.6576
#     Epoch 11/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.7514 - accuracy: 0.6432
#     Epoch 12/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.7375 - accuracy: 0.6484
#     Epoch 13/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6669 - accuracy: 0.6797
#     Epoch 14/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6544 - accuracy: 0.6771
#     Epoch 15/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6580 - accuracy: 0.6628
#     Epoch 16/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6494 - accuracy: 0.6654
#     Epoch 17/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6771 - accuracy: 0.6771
#     Epoch 18/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6284 - accuracy: 0.6823
#     Epoch 19/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6256 - accuracy: 0.6888
#     Epoch 20/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5985 - accuracy: 0.6992
#     Epoch 21/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6016 - accuracy: 0.7005
#     Epoch 22/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6075 - accuracy: 0.6875
#     Epoch 23/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5964 - accuracy: 0.7096
#     Epoch 24/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.6164 - accuracy: 0.6979
#     Epoch 25/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6069 - accuracy: 0.7018
#     Epoch 26/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5939 - accuracy: 0.7174
#     Epoch 27/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6296 - accuracy: 0.6927
#     Epoch 28/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6377 - accuracy: 0.6979
#     Epoch 29/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6077 - accuracy: 0.7148
#     Epoch 30/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5803 - accuracy: 0.7214
#     Epoch 31/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5968 - accuracy: 0.7070
#     Epoch 32/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5746 - accuracy: 0.7266
#     Epoch 33/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5845 - accuracy: 0.7279
#     Epoch 34/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5797 - accuracy: 0.7083
#     Epoch 35/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5681 - accuracy: 0.7253
#     Epoch 36/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5711 - accuracy: 0.7148
#     Epoch 37/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5993 - accuracy: 0.7018
#     Epoch 38/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5780 - accuracy: 0.7057
#     Epoch 39/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5649 - accuracy: 0.7148
#     Epoch 40/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6317 - accuracy: 0.7018
#     Epoch 41/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5551 - accuracy: 0.7318
#     Epoch 42/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5575 - accuracy: 0.7240
#     Epoch 43/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5537 - accuracy: 0.7214
#     Epoch 44/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5658 - accuracy: 0.7214
#     Epoch 45/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5623 - accuracy: 0.7096
#     Epoch 46/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5916 - accuracy: 0.7174
#     Epoch 47/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5549 - accuracy: 0.7357
#     Epoch 48/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5665 - accuracy: 0.7331
#     Epoch 49/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5731 - accuracy: 0.7005
#     Epoch 50/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5562 - accuracy: 0.7253
#     Epoch 51/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5440 - accuracy: 0.7422
#     Epoch 52/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.6000 - accuracy: 0.7109
#     Epoch 53/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5455 - accuracy: 0.7422
#     Epoch 54/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5529 - accuracy: 0.7318
#     Epoch 55/150
#     77/77 [==============================] - 0s 950us/step - loss: 0.5736 - accuracy: 0.7135
#     Epoch 56/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5381 - accuracy: 0.7357
#     Epoch 57/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5600 - accuracy: 0.7409
#     Epoch 58/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5618 - accuracy: 0.7266
#     Epoch 59/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.
150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4861 - accuracy: 0.7669
#     Epoch 124/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5058 - accuracy: 0.7669
#     Epoch 125/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4895 - accuracy: 0.7513
#     Epoch 126/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5109 - accuracy: 0.7565
#     Epoch 127/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4859 - accuracy: 0.7630
#     Epoch 128/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5102 - accuracy: 0.7552
#     Epoch 129/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4852 - accuracy: 0.7734
#     Epoch 130/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4924 - accuracy: 0.7578
#     Epoch 131/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4998 - accuracy: 0.7604
#     Epoch 132/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4943 - accuracy: 0.7656
#     Epoch 133/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4939 - accuracy: 0.7591
#     Epoch 134/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4822 - accuracy: 0.7721
#     Epoch 135/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4879 - accuracy: 0.7565
#     Epoch 136/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4873 - accuracy: 0.7669
#     Epoch 137/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.5145 - accuracy: 0.7565
#     Epoch 138/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.5253 - accuracy: 0.7331
#     Epoch 139/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.7565
#     Epoch 140/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4981 - accuracy: 0.7448
#     Epoch 141/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4848 - accuracy: 0.7682
#     Epoch 142/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4886 - accuracy: 0.7669
#     Epoch 143/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4818 - accuracy: 0.7617
#     Epoch 144/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4883 - accuracy: 0.7604
#     Epoch 145/150
#     77/77 [==============================] - 0s 1ms/step - loss: 0.4803 - accuracy: 0.7669
#     Epoch 146/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4804 - accuracy: 0.7643
#     Epoch 147/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4859 - accuracy: 0.7656
#     Epoch 148/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.7669
#     Epoch 149/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4762 - accuracy: 0.7682
#     Epoch 150/150
#     77/77 [==============================] - 0s 2ms/step - loss: 0.4807 - accuracy: 0.7656
#     24/24 [==============================] - 0s 2ms/step - loss: 0.4666 - accuracy: 0.7826
#     Accuracy: 78.26
#
# In \[14\]:
#
#     ...
#     # fit the keras model on the dataset without progress bars
#     model.fit(X, y, epochs=150, batch_size=10, verbose=0)
#     # evaluate the keras model
#     _, accuracy = model.evaluate(X, y, verbose=0)
#     ...
#
# Out\[14\]:
#
#     Ellipsis
#
# In \[15\]:
#
#     # Make Predictions
#
#     ...
#     # make probability predictions with the model
#     predictions = model.predict(X)
#     # round predictions
#     rounded = [round(x[0]) for x in predictions]
#
#     24/24 [==============================] - 0s 2ms/step
#
# In \[16\]:
#
#     ...
#     # make class predictions with the model
#     predictions = (model.predict(X) > 0.5).astype(int)
#
#     24/24 [==============================] - 0s 2ms/step
#
# In \[19\]:
#
#     # first neural network with keras make predictions
#     from numpy import loadtxt
#     from tensorflow.keras.models import Sequential
#     from tensorflow.keras.layers import Dense
#     # load the dataset
#     dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
#     # split into input (X) and output (y) variables
#     X = dataset[:,0:8]
#     y = dataset[:,8]
#     # define the keras model
#     model = Sequential()
#     model.add(Dense(12, input_shape=(8,), activation='relu'))
#     model.add(Dense(8, activation='relu'))
#     model.add(Dense(1, activation='sigmoid'))
#     # compile the keras model
#     model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
#     # fit the keras model on the dataset
#     model.fit(X, y, epochs=150, batch_size=10, verbose=0)
#     # make class predictions with the model
#     predictions = (model.predict(X) > 0.5).astype(int)
#     # summarize the first 5 cases
#     for i in range(5):
#         print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
#
#     24/24 [==============================] - 0s 2ms/step
#     [6.0, 148.0, 72.0, 35.0, 0.0, 33.6, 0.627, 50.0] => 1 (expected 1)
#     [1.0, 85.0, 66.0, 29.0, 0.0, 26.6, 0.351, 31.0] => 0 (expected 0)
#     [8.0, 183.0, 64.0, 0.0, 0.0, 23.3, 0.672, 32.0] => 1 (expected 1)
#     [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.167, 21.0] => 0 (expected 0)
#     [0.0, 137.0, 40.0, 35.0, 168.0, 43.1, 2.288, 33.0] => 1 (expected 1)
#
# In \[ \]:
#
#     # Specifically, we have learned the six key steps in using Keras to create a neural network or deep learning model step-by-step, including:
#
#     # How to load data
#     # How to define a neural network in Keras
#     # How to compile a Keras model using the efficient numerical backend
#     # How to train a model on data
#     # How to evaluate a model on data
#     # How to make predictions with the model
#
# In \[ \]:
#
#
#
# In \[ \]:
#
#
#
# In \[ \]:
